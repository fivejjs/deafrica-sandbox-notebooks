# %%
# !pip install xgboost -U
# Out:
# Collecting xgboost
#   Downloading xgboost-1.3.0.post0-py3-none-manylinux2010_x86_64.whl (157.5 MB)
#      |████████████████████████████████| 157.5 MB 110 kB/s s eta 0:00:01
# Requirement already satisfied, skipping upgrade: numpy in /env/lib/python3.6/site-packages (from xgboost) (1.18.5)
# Requirement already satisfied, skipping upgrade: scipy in /env/lib/python3.6/site-packages (from xgboost) (1.5.4)
# Installing collected packages: xgboost
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 1.2.1
#     Uninstalling xgboost-1.2.1:
#       Successfully uninstalled xgboost-1.2.1
# Successfully installed xgboost-1.3.0.post0
# WARNING: You are using pip version 20.2.4; however, version 20.3.1 is available.
# You should consider upgrading via the '/env/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.37.0.tar.gz (326 kB)
#      |████████████████████████████████| 326 kB 10.5 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /env/lib/python3.6/site-packages (from shap) (1.18.5)
# Requirement already satisfied: scipy in /env/lib/python3.6/site-packages (from shap) (1.5.4)
# Requirement already satisfied: scikit-learn in /env/lib/python3.6/site-packages (from shap) (0.23.2)
# Requirement already satisfied: pandas in /env/lib/python3.6/site-packages (from shap) (1.1.2)
# Requirement already satisfied: tqdm>4.25.0 in /env/lib/python3.6/site-packages (from shap) (4.54.0)
# Collecting slicer==0.0.3
#   Downloading slicer-0.0.3-py3-none-any.whl (11 kB)
# Requirement already satisfied: numba in /env/lib/python3.6/site-packages (from shap) (0.48.0)
# Requirement already satisfied: joblib>=0.11 in /env/lib/python3.6/site-packages (from scikit-learn->shap) (0.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /env/lib/python3.6/site-packages (from scikit-learn->shap) (2.1.0)
# Requirement already satisfied: pytz>=2017.2 in /env/lib/python3.6/site-packages (from pandas->shap) (2020.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /env/lib/python3.6/site-packages (from pandas->shap) (2.8.0)
# Requirement already satisfied: llvmlite<0.32.0,>=0.31.0dev0 in /env/lib/python3.6/site-packages (from numba->shap) (0.31.0)
# Requirement already satisfied: setuptools in /env/lib/python3.6/site-packages (from numba->shap) (50.3.2)
# Requirement already satisfied: six>=1.5 in /env/lib/python3.6/site-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Building wheels for collected packages: shap
#   Building wheel for shap (setup.py) ... done
#   Created wheel for shap: filename=shap-0.37.0-cp36-cp36m-linux_x86_64.whl size=463915 sha256=f39184cbabba3a6aa8b821a58d0fd37c71d21e048a8debe7dc38729c905e558b
#   Stored in directory: /home/jovyan/.cache/pip/wheels/9f/f0/81/55d1fce3ccceacb520abc45e88f3d2de2959cd079f712b5f85
# Successfully built shap
# Installing collected packages: slicer, shap
# Successfully installed shap-0.37.0 slicer-0.0.3
# WARNING: You are using pip version 20.2.4; however, version 20.3.1 is available.
# You should consider upgrading via the '/env/bin/python3 -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
df = pd.read_csv('results/training_data/gm_mads_two_seasons_training_data_20201123.csv', sep=' ')

# %%
df.head()
# Out:
#    Class    red_S1   blue_S1  green_S1    nir_S1  swir_1_S1  swir_2_S1  \
# 0    1.0  0.127868  0.077203  0.111521  0.301339   0.359995   0.281281
# 1    1.0  0.092796  0.055081  0.083433  0.249427   0.301828   0.225577
# 2    1.0  0.064913  0.049440  0.061939  0.155016   0.221684   0.153777
# 3    1.0  0.140223  0.059727  0.094393  0.255655   0.331874   0.274991
# 4    1.0  0.085796  0.061010  0.083576  0.201338   0.263326   0.182804
#
#    red_edge_1_S1  red_edge_2_S1  red_edge_3_S1  ...  red_edge_2_S2  \
# 0       0.185274       0.261258       0.291511  ...       0.257073
# 1       0.137628       0.219576       0.250052  ...       0.205870
# 2       0.088279       0.136593       0.153667  ...       0.096557
# 3       0.186378       0.238805       0.259208  ...       0.235046
# 4       0.129189       0.181609       0.203615  ...       0.136283
#
#    red_edge_3_S2   edev_S2   sdev_S2  bcdev_S2   NDVI_S2    LAI_S2  MNDWI_S2  \
# 0       0.283351  2.246781  7.064623  2.952092  0.224958  0.474304 -0.536428
# 1       0.229395  2.494673  7.128056  3.041181  0.181854  0.306314 -0.584877
# 2       0.106952  3.291765  6.074180  2.997704  0.170631  0.131878 -0.592229
# 3       0.253394  3.203019  7.648440  3.601598  0.261642  0.449042 -0.570569
# 4       0.151102  3.189153  6.454077  3.263663  0.193874  0.233971 -0.550557
#
#       rain_S2      slope
# 0  349.551086   3.004626
# 1  324.542236   2.946278
# 2  324.565796   3.173239
# 3  323.140869  19.110134
# 4  324.611938   3.004626
#
# [5 rows x 34 columns]
